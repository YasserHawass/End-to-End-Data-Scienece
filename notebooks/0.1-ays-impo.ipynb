# %%
# import essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle

# %% [markdown]
# # preprocess data, then convert into pickle

# %%
# import data from csv file
data = pd.read_csv('../data/raw/survey_results_public.csv', index_col=0)

# %%
# check duplicate rows
data.duplicated().sum()
# delete duplicate rows
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## Section 1 cleaning

# %%
# more info about 'UK_Country' and 'US_State'
# show unique values
# data['UK_Country'].unique()
data['US_State'].unique()
data[data['US_State'] == 'I do not reside in the United States']
# Out:
#                                         MainBranch  \
# ResponseId
# 1602        I am a student who is learning to code
# 35744               I am a developer by profession
# 41274                                None of these
# 60802               I am a developer by profession
# 65091       I am a student who is learning to code
# 66247                  I code primarily as a hobby
# 70414       I am a student who is learning to code
# 74591                  I code primarily as a hobby
#
#                                         Employment                   Country  \
# ResponseId
# 1602                            Student, full-time  United States of America
# 35744                           Employed full-time  United States of America
# 41274                          I prefer not to say  United States of America
# 60802       Not employed, and not looking for work  United States of America
# 65091                           Student, full-time  United States of America
# 66247                           Student, full-time  United States of America
# 70414                           Student, full-time  United States of America
# 74591                           Student, full-time  United States of America
#
#                                         US_State UK_Country  \
# ResponseId
# 1602        I do not reside in the United States        NaN
# 35744       I do not reside in the United States        NaN
# 41274       I do not reside in the United States        NaN
# 60802       I do not reside in the United States        NaN
# 65091       I do not reside in the United States        NaN
# 66247       I do not reside in the United States        NaN
# 70414       I do not reside in the United States        NaN
# 74591       I do not reside in the United States        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1602             Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 35744         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 41274                               Primary/elementary school   5 - 10 years
# 60802                                          Something else   5 - 10 years
# 65091       Some college/university study without earning ...  11 - 17 years
# 66247       Secondary school (e.g. American high school, G...   5 - 10 years
# 70414            Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 74591                               Primary/elementary school   5 - 10 years
#
#                                                     LearnCode  \
# ResponseId
# 1602                                                   School
# 35744                                                  School
# 41274                                 Other (please specify):
# 60802       Other online resources (ex: videos, blogs, etc...
# 65091       School;Online Courses or Certification;Books /...
# 66247       Other online resources (ex: videos, blogs, etc...
# 70414       Other online resources (ex: videos, blogs, etc...
# 74591       Other online resources (ex: videos, blogs, etc...
#
#                    YearsCode      YearsCodePro  ...                 Age  \
# ResponseId                                      ...
# 1602                       5               NaN  ...     18-24 years old
# 35744                     14                 1  ...   Prefer not to say
# 41274       Less than 1 year  Less than 1 year  ...                 NaN
# 60802                      3               NaN  ...   Prefer not to say
# 65091                      5               NaN  ...     25-34 years old
# 66247                      4               NaN  ...  Under 18 years old
# 70414                      7               NaN  ...     25-34 years old
# 74591                      6               NaN  ...  Under 18 years old
#
#                             Gender Trans                Sexuality  \
# ResponseId
# 1602                           NaN   NaN                      NaN
# 35744                          NaN   NaN                      NaN
# 41274                          NaN   NaN                      NaN
# 60802       Or, in your own words:    No        Prefer not to say
# 65091                          Man    No  Straight / Heterosexual
# 66247                          Man    No  Straight / Heterosexual
# 70414                          Man    No  Straight / Heterosexual
# 74591            Prefer not to say    No                      NaN
#
#                                Ethnicity      Accessibility  \
# ResponseId
# 1602                                 NaN                NaN
# 35744                                NaN                NaN
# 41274                                NaN                NaN
# 60802                  Prefer not to say  None of the above
# 65091       White or of European descent  None of the above
# 66247       White or of European descent  None of the above
# 70414                         East Asian  None of the above
# 74591                  Prefer not to say  None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1602                                                      NaN
# 35744                                                     NaN
# 41274                                                     NaN
# 60802       I have autism / an autism spectrum disorder (e...
# 65091                                       None of the above
# 66247       I have a concentration and/or memory disorder ...
# 70414                                       None of the above
# 74591       I have a concentration and/or memory disorder ...
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1602        Appropriate in length                        Easy
# 35744                    Too long                         NaN
# 41274                    Too long  Neither easy nor difficult
# 60802                    Too long  Neither easy nor difficult
# 65091       Appropriate in length                        Easy
# 66247       Appropriate in length                        Easy
# 70414       Appropriate in length  Neither easy nor difficult
# 74591                    Too long  Neither easy nor difficult
#
#            ConvertedCompYearly
# ResponseId
# 1602                       NaN
# 35744                      NaN
# 41274                      NaN
# 60802                      NaN
# 65091                      NaN
# 66247                      NaN
# 70414                      NaN
# 74591                      NaN
#
# [8 rows x 47 columns]

# %%
# check data for UK & citiies with no data
# data[data['Country']=='United Kingdom of Great Britain and Northern Ireland'].info()
# delete rows with Country = 'United Kingdom of Great Britain and Northern Ireland' and City is NaN
data.drop(data[(data['Country'] == 'United Kingdom of Great Britain and Northern Ireland') & (data['UK_Country'].isnull())].index, inplace=True)
# check data for US & citiies with no data
# data[data['Country'] == 'United States of America'].info()
# print(14920/15288*100) # USA has 14920 respondents who didn't answer with City name, we prefer to delete them for better bias & accuracate insights
# delete rows with Country = 'United States of America' and City is NaN
# data[(data['Country'] == 'United States of America') & (data['US_State'].isnull())]
data.drop(data[(data['Country'] == 'United States of America') & (data['US_State'].isnull())].index, inplace=True)
data.drop(data[(data['Country'] == 'United States of America') & (data['US_State'] == 'I do not reside in the United States')].index, inplace=True)

# %%
data.info()
# count the number of NaN values in each column
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82900 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    82900 non-null  object
#  1   Employment                    82900 non-null  object
#  2   Country                       82900 non-null  object
#  3   US_State                      14901 non-null  object
#  4   UK_Country                    4414 non-null   object
#  5   EdLevel                       82629 non-null  object
#  6   Age1stCode                    82729 non-null  object
#  7   LearnCode                     82454 non-null  object
#  8   YearsCode                     81173 non-null  object
#  9   YearsCodePro                  60955 non-null  object
#  10  DevType                       66244 non-null  object
#  11  OrgSize                       60476 non-null  object
#  12  Currency                      60795 non-null  object
#  13  CompTotal                     47067 non-null  float64
#  14  CompFreq                      52017 non-null  object
#  15  LanguageHaveWorkedWith        81845 non-null  object
#  16  LanguageWantToWorkWith        76351 non-null  object
#  17  DatabaseHaveWorkedWith        69226 non-null  object
#  18  DatabaseWantToWorkWith        58064 non-null  object
#  19  PlatformHaveWorkedWith        51880 non-null  object
#  20  PlatformWantToWorkWith        41439 non-null  object
#  21  WebframeHaveWorkedWith        61399 non-null  object
#  22  WebframeWantToWorkWith        51862 non-null  object
#  23  MiscTechHaveWorkedWith        46788 non-null  object
#  24  MiscTechWantToWorkWith        37815 non-null  object
#  25  ToolsTechHaveWorkedWith       72123 non-null  object
#  26  ToolsTechWantToWorkWith       65114 non-null  object
#  27  NEWCollabToolsHaveWorkedWith  80739 non-null  object
#  28  NEWCollabToolsWantToWorkWith  72587 non-null  object
#  29  OpSys                         82766 non-null  object
#  30  NEWStuck                      82537 non-null  object
#  31  NEWSOSites                    82651 non-null  object
#  32  SOVisitFreq                   81906 non-null  object
#  33  SOAccount                     82012 non-null  object
#  34  SOPartFreq                    67221 non-null  object
#  35  SOComm                        81810 non-null  object
#  36  NEWOtherComms                 82327 non-null  object
#  37  Age                           81974 non-null  object
#  38  Gender                        81863 non-null  object
#  39  Trans                         80275 non-null  object
#  40  Sexuality                     73038 non-null  object
#  41  Ethnicity                     79090 non-null  object
#  42  Accessibility                 77231 non-null  object
#  43  MentalHealth                  76558 non-null  object
#  44  SurveyLength                  81243 non-null  object
#  45  SurveyEase                    81471 non-null  object
#  46  ConvertedCompYearly           46732 non-null  float64
# dtypes: float64(2), object(45)
# memory usage: 32.4+ MB
# MainBranch                          0
# Employment                          0
# Country                             0
# US_State                        67999
# UK_Country                      78486
# EdLevel                           271
# Age1stCode                        171
# LearnCode                         446
# YearsCode                        1727
# YearsCodePro                    21945
# DevType                         16656
# OrgSize                         22424
# Currency                        22105
# CompTotal                       35833
# CompFreq                        30883
# LanguageHaveWorkedWith           1055
# LanguageWantToWorkWith           6549
# DatabaseHaveWorkedWith          13674
# DatabaseWantToWorkWith          24836
# PlatformHaveWorkedWith          31020
# PlatformWantToWorkWith          41461
# WebframeHaveWorkedWith          21501
# WebframeWantToWorkWith          31038
# MiscTechHaveWorkedWith          36112
# MiscTechWantToWorkWith          45085
# ToolsTechHaveWorkedWith         10777
# ToolsTechWantToWorkWith         17786
# NEWCollabToolsHaveWorkedWith     2161
# NEWCollabToolsWantToWorkWith    10313
# OpSys                             134
# NEWStuck                          363
# NEWSOSites                        249
# SOVisitFreq                       994
# SOAccount                         888
# SOPartFreq                      15679
# SOComm                           1090
# NEWOtherComms                     573
# Age                               926
# Gender                           1037
# Trans                            2625
# Sexuality                        9862
# Ethnicity                        3810
# Accessibility                    5669
# MentalHealth                     6342
# SurveyLength                     1657
# SurveyEase                       1429
# ConvertedCompYearly             36168
# dtype: int64

# %%
# show uniques for MainBranch
data['MainBranch'].unique()
# show uniques for Employment
data['Employment'].unique()
# show how many Employments are null
# data[data['Employment'].isnull()]['SurveyEase'].value_counts()
# remove rows with Employment null
data.drop(data[data['Employment'].isnull()].index, inplace=True)

# %% [markdown]
# ## Section 2 cleaning

# %%
# convert data into pickle file
data.to_pickle('../data/interim/data.pkl')

# %% [markdown]
# # Read Data again from pickle file and explore it
